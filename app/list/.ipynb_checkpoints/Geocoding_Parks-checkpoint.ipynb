# %% [markdown]
# # Geocoding my park list so I can make a nice map on my site
#
# *Aniket Pant*

# %%
# !pip install pandas geopy

# %%
import argparse
import time
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

def build_query(park: str, district: str) -> str:
    # District should be "Urbana" or "Champaign".
    return f"{park}, {district}, Champaign County, Illinois, USA"

# %%
df = pd.read_csv("list.txt", sep = "\t")

# Basic validation
for col in ("Park", "District"):
    if col not in df.columns:
        print(f"Input CSV must contain a '{col}' column.")

user_agent = f"cu-parks-geocoder/1.0 pant.aniket@gmail.com)"
geolocator = Nominatim(user_agent=user_agent, timeout=10)
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1.1, max_retries=2, error_wait_seconds=2.0)

lats, lons, addrs, queries = [], [], [], []

# %%
df
# Out:
#     Rank                                 Park  Approx. size (acres)  \
# 0      1                    Crystal Lake Park                144.00
# 1      2                     Meadowbrook Park                130.00
# 2      3                           Dodds Park                104.00
# 3      4                      Centennial Park                 69.60
# 4      5                          Weaver Park                 60.00
# 5      6           Dog Park/Perkins Road Site                 60.00
# 6      7                        Heritage Park                 41.60
# 7      8                   Porter Family Park                 38.20
# 8      9                         Kaufman Park                 29.10
# 9     10                         Robeson Park                 24.10
# 10    11                          Mattis Park                 22.30
# 11    12                          Hessel Park                 22.20
# 12    13                          AMBUCS Park                 22.00
# 13    14                           Zahnd Park                 20.60
# 14    15                   Commissioners Park                 20.00
# 15    16                         Prairie Park                 20.00
# 16    17  Robeson Meadows West Detention Park                 19.50
# 17    18                    Sunset Ridge Park                 19.40
# 18    19                       Morrissey Park                 19.00
# 19    20                        Spalding Park                 16.80
# 20    21                        Douglass Park                 15.50
# 21    22                        Johnston Park                 15.10
# 22    23                         Lohmann Park                 15.00
# 23    24                       West Side Park                 13.90
# 24    25                 Chief Shemauger Park                 13.00
# 25    26                           Blair Park                 11.00
# 26    27                     South Ridge Park                 11.00
# 27    28                           Carle Park                 11.00
# 28    29                            Noel Park                 10.80
# 29    30                  Human Kinetics Park                  8.90
# 30    31                          Powell Park                  8.00
# 31    32                            King Park                  8.00
# 32    33                         Toalson Park                  7.70
# 33    34              Champaign Bark District                  6.90
# 34    35                 Turnberry Ridge Park                  6.10
# 35    36                        Hallbeck Park                  6.00
# 36    37             Larson (Wheatfield) Park                  5.00
# 37    38                         Victory Park                  5.00
# 38    39                           Hazel Park                  4.90
# 39    40                          Eisner Park                  4.90
# 40    41                    Garden Hills Park                  4.50
# 41    42                            Bian Park                  4.20
# 42    43                           Clark Park                  4.00
# 43    44                           Scott Park                  3.90
# 44    45                      Washington Park                  3.80
# 45    46                     Town Center Park                  3.76
# 46    47                    Greenbelt #1 Park                  3.44
# 47    48                        Mullikin Park                  3.30
# 48    49                            Leal Park                  3.00
# 49    50                         Canaday Park                  3.00
#
#      District Visited (+ date)
# 0      Urbana                Y
# 1      Urbana                Y
# 2   Champaign                Y
# 3   Champaign              NaN
# 4      Urbana              NaN
# 5      Urbana              NaN
# 6   Champaign              NaN
# 7   Champaign              NaN
# 8   Champaign              NaN
# 9   Champaign              NaN
# 10  Champaign              NaN
# 11  Champaign              NaN
# 12     Urbana              NaN
# 13  Champaign              NaN
# 14  Champaign              NaN
# 15     Urbana              NaN
# 16  Champaign              NaN
# 17  Champaign                Y
# 18  Champaign              NaN
# 19  Champaign              NaN
# 20  Champaign              NaN
# 21  Champaign              NaN
# 22     Urbana              NaN
# 23  Champaign              NaN
# 24     Urbana              NaN
# 25     Urbana              NaN
# 26     Urbana              NaN
# 27     Urbana     Y (08/25/25)
# 28  Champaign              NaN
# 29  Champaign              NaN
# 30  Champaign              NaN
# 31     Urbana              NaN
# 32  Champaign              NaN
# 33  Champaign              NaN
# 34  Champaign              NaN
# 35  Champaign              NaN
# 36     Urbana              NaN
# 37     Urbana              NaN
# 38  Champaign              NaN
# 39  Champaign              NaN
# 40  Champaign              NaN
# 41  Champaign              NaN
# 42  Champaign              NaN
# 43  Champaign                Y
# 44  Champaign              NaN
# 45  Champaign              NaN
# 46  Champaign              NaN
# 47  Champaign              NaN
# 48     Urbana              NaN
# 49     Urbana              NaN

# %%
for idx, row in df.iterrows():
    park = str(row["Park"]).strip()
    district = str(row["District"]).strip()
    q = build_query(park, district)
    queries.append(q)

    loc = None
    try:
        # Primary attempt
        loc = geocode(q, country_codes="us", addressdetails=False, exactly_one=True)
        # Fallback: try city without county if needed
        if loc is None:
            fallback_q = f"{park}, {district}, Illinois, USA"
            loc = geocode(fallback_q, country_codes="us", addressdetails=False, exactly_one=True)
    except Exception as e:
        print(f"[{idx}] Error geocoding '{q}': {e}")

    if loc is None:
        lats.append(None)
        lons.append(None)
        addrs.append(None)
        print(f"[{idx}] ⚠️ No result for: {q}")
    else:
        lats.append(loc.latitude)
        lons.append(loc.longitude)
        addrs.append(loc.address)
        print(f"[{idx}] ✓ {park} → ({loc.latitude:.6f}, {loc.longitude:.6f})")

    # RateLimiter already delays, but a tiny extra buffer never hurts:
    time.sleep(0.05)
# Out:
# [0] ✓ Crystal Lake Park → (40.122294, -88.208934)
# [1] ✓ Meadowbrook Park → (40.079996, -88.204586)
# [2] ✓ Dodds Park → (40.131843, -88.282281)
# [3] ✓ Centennial Park → (40.104047, -88.285611)
# [4] ✓ Weaver Park → (40.109609, -88.179147)
# [5] ⚠️ No result for: Dog Park/Perkins Road Site, Urbana, Champaign County, Illinois, USA
# [6] ✓ Heritage Park → (40.124156, -88.283614)
# [7] ✓ Porter Family Park → (40.086212, -88.330602)
# [8] ✓ Kaufman Park → (40.115962, -88.288118)
# [9] ✓ Robeson Park → (40.090664, -88.292305)
# [10] ✓ Mattis Park → (40.087320, -88.252530)
# [11] ✓ Hessel Park → (40.099636, -88.250513)
# [12] ✓ AMBUCS Park → (40.117042, -88.193401)
# [13] ✓ Zahnd Park → (40.081725, -88.312557)
# [14] ⚠️ No result for: Commissioners Park, Champaign, Champaign County, Illinois, USA
# [15] ✓ Prairie Park → (40.106655, -88.185099)
# [16] ⚠️ No result for: Robeson Meadows West Detention Park, Champaign, Champaign County, Illinois, USA
# [17] ✓ Sunset Ridge Park → (40.133073, -88.313575)
# [18] ✓ Morrissey Park → (40.085673, -88.265378)
# [19] ✓ Spalding Park → (40.124413, -88.251636)
# [20] ✓ Douglass Park → (40.124453, -88.230514)
# [21] ⚠️ No result for: Johnston Park, Champaign, Champaign County, Illinois, USA
# [22] ✓ Lohmann Park → (40.095425, -88.183618)
# [23] ✓ West Side Park → (40.117284, -88.248474)
# [24] ✓ Chief Shemauger Park → (40.121399, -88.197190)
# [25] ✓ Blair Park → (40.100094, -88.206064)
# [26] ✓ South Ridge Park → (40.079879, -88.182139)
# [27] ✓ Carle Park → (40.103858, -88.211454)
# [28] ✓ Noel Park → (40.079452, -88.261623)
# [29] ✓ Human Kinetics Park → (40.131782, -88.240060)
# [30] ✓ Powell Park → (40.122920, -88.299800)
# [31] ✓ King Park → (40.121952, -88.221304)
# [32] ✓ Toalson Park → (40.152540, -88.252185)
# [33] ✓ Champaign Bark District → (40.082338, -88.329152)
# [34] ✓ Turnberry Ridge Park → (40.105672, -88.308264)
# [35] ✓ Hallbeck Park → (40.079386, -88.294757)
# [36] ⚠️ No result for: Larson (Wheatfield) Park, Urbana, Champaign County, Illinois, USA
# [37] ✓ Victory Park → (40.111940, -88.197059)
# [38] ✓ Hazel Park → (40.127920, -88.244700)
# [39] ✓ Eisner Park → (40.117334, -88.268070)
# [40] ✓ Garden Hills Park → (40.137799, -88.273679)
# [41] ✓ Bian Park → (40.097795, -88.301195)
# [42] ✓ Clark Park → (40.107271, -88.262503)
# [43] ✓ Scott Park → (40.112039, -88.236230)
# [44] ✓ Washington Park → (40.106046, -88.236180)
# [45] ✓ Town Center Park → (40.144563, -88.249700)
# [46] ✓ Greenbelt #1 Park → (40.120565, -88.285847)
# [47] ✓ Mullikin Park → (40.089511, -88.320754)
# [48] ✓ Leal Park → (40.115670, -88.210398)
# [49] ✓ Canaday Park → (40.110678, -88.188040)

# %%
out = df.copy()
# out["geocode_query"] = queries
out["lat"] = lats
out["lon"] = lons
# out["matched_address"] = addrs
out.to_csv("geocoded_list.txt", index=False)
print(f"\nDone. Wrote {len(out)} rows to geocoded_list.txt")
# Out:
# Done. Wrote 50 rows to geocoded_list.txt

# %%
# i wrote some more out by hand (around 5 rows) that nominatim could not find...
